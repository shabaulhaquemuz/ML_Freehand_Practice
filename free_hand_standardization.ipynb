# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Social_Network_Ads.csv")

# %%
df.sample(2)
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 2   15668575  Female   26            43000          0
# 76  15746737    Male   18            52000          0

# %%
df.head(2)
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
df=df.iloc[:,2:]

# %%
df.sample(2)
# Out:
#      Age  EstimatedSalary  Purchased
# 20    45            22000          1
# 222   37           144000          1

# %%
df.head(2)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns="Purchased"),df["Purchased"],test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (320, 2)

# %%
x_test.shape
# Out:
# (80, 2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
print(x_train.head(2))
# Out:
#     Age  EstimatedSalary
# 3    27            57000
# 18   46            28000

# %%
print(x_train_scaled.head(2))  # error because after standardization it got converted to numpy array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(x_train_scaled.head(2))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
print(x_train_scaled[0:2]) #printing just two rows of numpy array
# Out:
# [[-1.06675246 -0.38634438]
#  [ 0.79753468 -1.22993871]]

# %%
print(x_train_scaled)
# Out:
# [[-1.06675246 -0.38634438]
#  [ 0.79753468 -1.22993871]
#  [ 0.11069205  1.853544  ]
#  [ 0.60129393 -0.90995465]
#  [ 1.87685881 -1.28811763]
#  [-0.57615058  1.44629156]
#  [ 0.3069328  -0.53179168]
#  [ 0.99377543  0.10817643]
#  [-1.16487283  0.45724994]
#  [-1.55735433  0.31180264]
#  [ 1.0918958   0.45724994]
#  [-0.18366908 -0.47361276]
#  [ 0.20881242 -0.32816546]
#  [ 0.3069328   0.28271318]
#  [-1.16487283 -1.57901222]
#  [ 0.11069205  0.25362372]
#  [ 2.07309956  1.73718616]
#  [ 0.40505317 -0.18271817]
#  [ 1.4843773   2.11534913]
#  [-0.37990983  1.21357589]
#  [ 1.87685881  1.50447048]
#  [ 0.11069205  0.02090805]
#  [ 0.89565505 -1.31720709]
#  [-1.36111358 -1.49174384]
#  [-0.18366908 -0.5899706 ]
#  [-0.57615058  2.31897535]
#  [ 0.99377543 -1.20084925]
#  [-0.77239133  1.06812859]
#  [ 2.17121993 -1.05540195]
#  [ 0.01257167 -0.26998655]
#  [-0.4780302  -1.14267033]
#  [ 0.11069205  0.02090805]
#  [ 1.68061805 -0.90995465]
#  [ 1.0918958  -0.90995465]
# ...

# %%
#converting the numpy array into dataframe now
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train_scaled.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 #converting the numpy array into dataframe now
# ----> 2 x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train_scaled.columns)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)

# %%
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
print(round(x_train.describe(),1))
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    37.9          70281.2
# std     10.2          34430.6
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          71000.0
# 75%     45.0          88000.0
# max     60.0         150000.0

# %%
print(round(x_train_scaled.describe(),1))
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    -0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.7              0.5
# max      2.2              2.3
